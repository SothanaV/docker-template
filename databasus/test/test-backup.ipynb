# %%
import pandas as pd

# %%
con = "postgresql://postgesql:qwer1234@localhost:5432/postgesql"

# %%
pd.read_sql_query("""
SELECT * FROM information_schema.tables
""", con)
# Out:
#     table_catalog        table_schema             table_name  table_type  \
# 0       postgesql          pg_catalog           pg_statistic  BASE TABLE
# 1       postgesql          pg_catalog                pg_type  BASE TABLE
# 2       postgesql          pg_catalog       pg_foreign_table  BASE TABLE
# 3       postgesql          pg_catalog              pg_authid  BASE TABLE
# 4       postgesql          pg_catalog              pg_shadow        VIEW
# ..            ...                 ...                    ...         ...
# 208     postgesql  information_schema  foreign_table_options        VIEW
# 209     postgesql  information_schema         foreign_tables        VIEW
# 210     postgesql  information_schema      _pg_user_mappings        VIEW
# 211     postgesql  information_schema   user_mapping_options        VIEW
# 212     postgesql  information_schema          user_mappings        VIEW
#
#     self_referencing_column_name reference_generation  \
# ...

# %%
df = pd.read_json('https://github.com/storemesh/masterdata/raw/refs/heads/main/master_area_th.json')
df
# Out:
#       AD_LEVEL   TA_ID        TAMBON_T     TAMBON_E  AM_ID       AMPHOE_T  \
# 0            4  910106  ต. เกาะสาหร่าย     Ko Sarai   9101           None
# 1            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# 2            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# 3            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# 4            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# ...        ...     ...             ...          ...    ...            ...
# 7763         4  710803       ต. ไล่โว่       Lai Wo   7108  อ. สังขละบุรี
# 7764         4  710705         ต. ชะแล       Chalae   7107   อ. ทองผาภูมิ
# 7765         4  610607   ต. แก่นมะกรูด  Kaen Makrut   6106     อ. บ้านไร่
# 7766         4  630805    ต. แม่ละมุ้ง   Mae Lamung   6308     อ. อุ้มผาง
# 7767         4  630305       ต. บ้านนา       Ban Na   6303      อ. สามเงา
#
#             AMPHOE_E  CH_ID    CHANGWAT_T    CHANGWAT_E     LAT     LONG
# ...

# %%
df.to_sql('dim_area', con=con, index=False)
# Out:
# 768

# %%
import psycopg2

# %%
conn = psycopg2.connect(con)
conn
# Out:
# <connection object at 0x11eee4ac0; dsn: 'user=postgesql password=xxx dbname=postgesql host=localhost port=5432', closed: 0>

# %%
cur = conn.cursor()

# %%
cur.execute("""
TRUNCATE TABLE dim_area
""")

# %%
conn.commit()

# %%
pd.read_sql_query("""
SELECT * FROM dim_area
""",con)
# Out:
#       AD_LEVEL   TA_ID        TAMBON_T     TAMBON_E  AM_ID       AMPHOE_T  \
# 0            4  910106  ต. เกาะสาหร่าย     Ko Sarai   9101           None
# 1            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# 2            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# 3            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# 4            4  210114     ต. มาบตาพุด    Maptaphut   2101  อ. เมืองระยอง
# ...        ...     ...             ...          ...    ...            ...
# 7763         4  710803       ต. ไล่โว่       Lai Wo   7108  อ. สังขละบุรี
# 7764         4  710705         ต. ชะแล       Chalae   7107   อ. ทองผาภูมิ
# 7765         4  610607   ต. แก่นมะกรูด  Kaen Makrut   6106     อ. บ้านไร่
# 7766         4  630805    ต. แม่ละมุ้ง   Mae Lamung   6308     อ. อุ้มผาง
# 7767         4  630305       ต. บ้านนา       Ban Na   6303      อ. สามเงา
#
#             AMPHOE_E  CH_ID    CHANGWAT_T    CHANGWAT_E     LAT     LONG
# ...
